# %%
# !pip install tensorflow
# !pip install scikit-learn
# !pip install matplotlib
# !pip install prophet
# !pip install yfinance
# !pip install statsmodels

# %%
import warnings
warnings.filterwarnings ("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import IsolationForest
from statsmodels.tsa.arima.model import ARIMA
from prophet import Prophet
#LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
path = ".\\"
TXN_CSV = "datasets\expense_transactions_data.csv"
MONTHLY_CSV = "datasets\monthly_category_expenses_data.csv"

# TXN_CSV.head()

# %%
# SETTINGS
FORECAST_MONTHS = 12     # forecast horizon (months)




LSTM_WINDOW = 6  
#how many past months to predict next month
LSTM_EPOCHS = 60
LSTM_BATCH = 16
TOP_CATEGORIES= 8 #focus on top categories for forecasting plots (reduce noise)
TEST_MONTHS = 6 #last N months kept for testing model performance
# SMALL HELPERS (few functions only)
def pick_col (df, candidates):
    """Pick the first existing column from candidates (case-insensitive)."""
    cols = {c.lower(): c for c in df.columns}
    for cand in candidates:
         if cand.lower() in cols:
            return cols[cand.lower()]
    return None
   

    



def clean_amount(s):
    """Convert amounts like '1,234', '500', '$12.3' to float safely, """


    s = s.astype(str)
    s = s.str.replace(",", "", regex=False)
    s = s.str.replace("₹", "", regex=False).str.replace("$", "", regex=False)
    s = s.str.replace("INR", "", regex=False).str.replace("Rs.", "", regex=False)
    s = s.str.strip()
    return pd.to_numeric(s, errors="coerce")


def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def mape(y_true, y_pred):
    y_true = np.array(y_true, dtype = float)
    y_pred = np.array(y_pred, dtype = float)
    return np.mean(np.abs((y_true - y_pred) / (y_true + 1e-9))) * 100


def create_lstm_sequences(arr_1d, window):
    X, y = [], []
    for i in range(len(arr_1d) - window):
        X.append(arr_1d[i:i + window])
        y.append(arr_1d[i + window])
    return np.array(X), np.array(y)

# %%
#-------------------------------------------------------------------------------------------------------------------------
#LOAD DATASETS
#-------------------------------------------------------------------------------------------------------------------------

txn =pd.read_csv(path + TXN_CSV)
monthly = pd.read_csv(path + MONTHLY_CSV)


txn.columns = [c.strip() for c in txn.columns]
monthly.columns = [c.strip() for c in monthly.columns]


print("Trancsaction dataset shape : ", txn.shape)
print("Monthly dataset shape : ", monthly.shape)

txn.head()
monthly.head()
# Out:
# Trancsaction dataset shape :  (7366, 8)
# Monthly dataset shape :  (1008, 5)
#    year  month   period       category  monthly_expense_inr
# 0  2019      1  2019-01           Rent             18840.02
# 1  2019      1  2019-01      Groceries              9035.66
# 2  2019      1  2019-01      Utilities              4110.39
# 3  2019      1  2019-01      Transport              2570.13
# 4  2019      1  2019-01  Entertainment              1896.88

# %%
#-------------------------------------------------------------------------------------------------------------------------
# STANDARDIZE MONTHLY DATA (Date/Month, Category, Amount)
#-------------------------------------------------------------------------------------------------------------------------

# Try to detect monthly columns
month_col = pick_col(monthly, ["Month", "Date", "YearMonth", "MonthYear", "Period"])
cat_col = pick_col(monthly, ["Category", "ExpenseCategory", "Type"])
amt_col = pick_col(
    monthly,
    ["Amount", "Expense", "Total", "Total_Expense",
     "Spend", "Value", "monthly_expense_inr"]
)




if month_col is None or cat_col is None or amt_col is None:
    raise ValueError(
        "Could not auto-detect required columns in mmonthly dataset."
        "Expected something like Month/Date , Category, Amount."

    )

monthly = monthly[[month_col, cat_col, amt_col]].copy()
monthly = monthly.rename(columns = {month_col: "Month", cat_col: "Category", amt_col: "Amount"})


# parse MOnth column, to allow formats like yy-mm, mm-yy,yyyy-mm-dd, etc
monthly["Month"] = pd.to_datetime(monthly["Month"], errors="coerce", dayfirst = True)
monthly ["Month"] = pd.to_datetime(monthly["Month"], errors="coerce",dayfirst=True)
monthly = monthly.dropna(subset=["Month"]).copy()
# convert to month start (monthly index)
monthly["Month"] = monthly["Month"].dt.to_period("M").dt.to_timestamp()
monthly["Category"] = monthly["Category"].astype(str).str.strip()
monthly["Amount"] = clean_amount(monthly["Amount"])
monthly = monthly.dropna(subset=["Amount"]).copy()



monthly = monthly[monthly["Amount"] >= 0].copy()
# Remove duplicates (same month, category) by summing (safer than drop)
monthly = monthly.groupby(["Month", "Category"], as_index=False)["Amount"].sum()
monthly = monthly.sort_values(["Category", "Month"]).reset_index(drop=True)
print("\nMonthly data (cleaned) sample:")

print(monthly.head())


# -----------------------------------------------------------------------
# OPTIONAL: STANDARDIZE TRANSACTION DATA (for classification/anomaly)
# -----------------------------------------------------------------------
# Detect columns in transaction dataset
txn_date_col  = pick_col(txn, ["Date", "TransactionDate", "TxnDate","Timestamp"])
txn_cat_col = pick_col(txn, ["Category", "ExpenseCategory", "Type"])
txn_amt_col  = pick_col(txn, ["Amount", "Expense", "Price", "Value","Debit"])
txn_desc_col = pick_col(txn, ["Description", "Merchant", "Narration", "Notes", "Item", "Details"])

if txn_date_col and txn_amt_col :
    txn2 = txn.copy()



    txn2[txn_date_col] = pd.to_datetime(txn2 [txn_date_col], errors="coerce", dayfirst=True)
    txn2[txn_amt_col] = clean_amount(txn2 [txn_amt_col])
    txn2 = txn2.dropna(subset=[txn_date_col, txn_amt_col]).copy()
    txn2 = txn2[txn2[txn_amt_col] >= 0].copy()
else:
    txn2 = None



# BUILD A "WIDE" MONTHLY TABLE: rows=Month, cols=Category,values=Amount
#
wide = monthly.pivot_table(index="Month", columns="Category",values="Amount", aggfunc="sum").fillna (0.0)
wide = wide.sort_index()
# total expense per month
wide["TOTAL_EXPENSE"] = wide.sum(axis=1)
# also compute yearly totals
yearly = wide.resample("YE").sum()
yearly.index = yearly.index.year
print("\nDate range (monthly):", wide.index.min().date(), "to", wide.index.max().date())
print("Number of categories:", wide.shape[1] - 1)


print("columns:", wide.columns.tolist())
if 'TOTAL_EXPENSE' not in wide.columns:
    # compute row-wise total across numeric columns (safe against non-numeric cols)
    num_cols = wide.select_dtypes(include='number')
    if num_cols.shape[1] == 0:
        raise ValueError("No numeric columns available to compute TOTAL_EXPENSE")
    wide['TOTAL_EXPENSE'] = num_cols.sum(axis=1)
# EDA
# Out:
# Monthly data (cleaned) sample:
#        Month       Category     Amount
# 0 1970-01-01         Dining  359735.11
# 1 1970-01-01      Education  151664.92
# 2 1970-01-01  Entertainment  206855.22
# 3 1970-01-01      Groceries  896424.92
# 4 1970-01-01     Healthcare  198765.60
#
# Date range (monthly): 1970-01-01 to 1970-01-01
# Number of categories: 12
# columns: ['Dining', 'Education', 'Entertainment', 'Groceries', 'Healthcare', 'Insurance', 'Miscellaneous', 'Rent', 'Subscriptions', 'Transport', 'Travel', 'Utilities', 'TOTAL_EXPENSE']

# %%
import pandas as pd
monthly = pd.read_csv("datasets/monthly_category_expenses_data.csv")
print(monthly.columns.tolist())


# THIS CELL CAN BE DELETED LATER ON
# IT WAS ONLY FOR KNOWING THE COLUMN NAMES
if "TOTAL_EXPENSE" not in yearly.columns:
    num_cols = yearly.select_dtypes(include="number")
    yearly["TOTAL_EXPENSE"] = num_cols.sum(axis=1)
# Out:
# ['year', 'month', 'period', 'category', 'monthly_expense_inr']

# %%
# EDA
#
print("\n--- EDA ---")
# Total expense trend
plt.figure(figsize= (10,4))
plt.plot(wide.index, wide["TOTAL_EXPENSE"])
plt.title("Total Monthly Expense Trend")
plt.xlabel("Month")
plt.ylabel("Expense")
plt.tight_layout()
plt.show()


# Total categories by spend
cat_totals = wide.drop(columns=["TOTAL_EXPENSE"]).sum().sort_values(ascending=False)
top_cats = cat_totals.head(TOP_CATEGORIES).index.tolist()

plt.figure(figsize=(10,4))
cat_totals.head(TOP_CATEGORIES).plot(kind="bar")
plt.title("Top Categories by Total Spend")
plt.xlabel("Category")
plt.ylabel("Total Spend")
plt.tight_layout()
plt.show()
# Out:
# --- EDA ---

# %%
# Correlation across top categories

if len(top_cats) >= 2:
    corr = wide[top_cats].corr()
    plt.figure(figsize=(6,4))
    plt.imshow(corr.values)
    plt.title("Correlation (Top Categories)")
    plt.xticks (range (len(corr.columns)), corr.columns, rotation=45,
    ha="right")
    plt.yticks (range (len(corr.index)), corr.index)
    plt.colorbar ()
    plt.tight_layout()
    plt.show()


if len(top_cats) >= 2:
    corr = wide[top_cats].corr()

    plt.figure(figsize=(6,4))
    plt.imshow(corr, aspect="auto")
    plt.title("Correlation Top Categories")
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha="right")
    plt.yticks(range(len(corr.index)), corr.index)
    plt.colorbar()
    plt.tight_layout()
    plt.show()
else:
    print("Not enough categories for correlation plot")

# Yearly totals (TOTAL_EXPENSE)
# plt.figure(figsize=(8,4))
# plt.bar(yearly.index.astype(str), yearly ["TOTAL_EXPENSE"].values)
# plt.title("Yearly Total Expenses")
# plt.xlabel("Year")
# plt.ylabel("Total Expense")
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

plt.figure(figsize=(8,4))
plt.bar(yearly.index.astype(str), yearly["TOTAL_EXPENSE"].values)
plt.title("Yearly Total Expenses")
plt.xlabel("Year")
plt.ylabel("Total Expense")
plt.xticks(rotation=45)
plt.tight_layout()
plt.imshow(corr, vmin=-1, vmax=1, aspect="auto")

plt.show()

# %%
# Correlation across top categories
if len(top_cats) >= 2:
    corr = wide[top_cats].corr()

    # replace NaN correlations
    corr = corr.fillna(0)

    plt.figure(figsize=(7,5))
    plt.imshow(corr, aspect="auto")
    plt.title("Correlation Top Categories")

    plt.xticks(
        range(len(corr.columns)),
        corr.columns,
        rotation=45,
        ha="right"
    )
    plt.yticks(range(len(corr.index)), corr.index)

    plt.colorbar(label="Correlation")
    plt.tight_layout()
    plt.imshow(corr, vmin=-1, vmax=1, aspect="auto")

    plt.show()
else:
    print("Not enough categories for correlation plot")

# %%
print("\n--- Forecasting (TOTAL_EXPENSE) ---")
# Out:
# --- Forecasting (TOTAL_EXPENSE) ---

# %%
#Modeling helpers (per category forecasting)



def train_test_split(series, test_months):
    series = series.dropna()
    if len(series) <= test_months + 12:
        #not enough data: keep at least something
        test_months = max(1,min(test_months, len(series)//4))
    train = series.iloc[:-test_months]
    test = series.iloc[-test_months:]
    return train, test

def regression_forecast_monthly(series,months_ahead=12,test_months=6):
    s=series.copy()
    df=pd.DataFrame({"y":s})
    df["lag1"]=df["y"].shift(1)
    df["lag2"]=df["y"].shift(2)
    df["lag3"]=df["y"].shift(3)
    df["roll3"]=df["y"].rolling(3).mean()
    df["month_num"]=df.index.month
    df=df.dropna().copy()

    train_df,test_df=df.iloc[:-test_months],df.iloc[-test_months:]
    x_train=train_df[["lag1","lag2","lag3","roll3","month_num"]].values
    y_train=train_df["y"].values
    x_train=train_df[["lag1","lag2","lag3","roll3","month_num"]].values
    y_train=train_df["y"].values


    model=linearRegression()
    model.fit(x_train,y_train)
    pred_test=model.predict(X_test)
    # iterative future forecast 
    last=df.iloc[-1].copy()
    last_date=df.index[-1]
    future_preds=[]
    last_y=df["y"].copy()

    for i in range(months_ahead):
        next_data=(last_date + pd.offsets.monthBegin(1)).to_period("M").to_timestamp()
        # build features from last y 
        lag1 =last_y. iloc[-1] 
        lag2 =last_y. iloc[-2] if len(last_y) >=2 else lag1
        lag3 =last_y. iloc[-3] if len(last_y) >=3 else lag2
        roll3 =last_y. iloc[-3:] .mean()if len(last_y) >=3 else last_y.mean()
        month_num=next_data.month
        x=np.array([[lag1,lag2,lag3,roll3,month_num]])
        yhat=float(model.predict(x)[0])
        yhat=max(0.0,yhat)

        future_preds.append((next_data, yhat))
        last_y = pd.concat([last_y, pd.Series([yhat],index= [next_date])])
        last_date=next_date
        future = pd.Series({ d:v  for d, v in future_preds} )
        return pred_test, y_test, future


    """
    simple regression:
    y(t) predicted from:
    —  lag 1, lag2, lag 3
    —  month number (seasonality proxy)
    —  rolling mean (3)
    """

# %%
# from modulefinder import test


def arima_forecast(series, months_ahead=12, test_months=6, order= (2,1,2)):
    train, test = train_test_split_series(series, test_months)
    model = ARIMA(train, order=order).fit() 
    pred_test = model.forecast(steps=len(test))
    future = model.forecast (steps=len (test) + months_ahead)
    future = future.iloc[len(test): ]


    future.index = pd.date_range(start=series.index.max() +pd.offsets.MonthBegin(1), periods=months_ahead,freq="MS")	
    pred_test.index = test.index
    return pred_test.values,test.values,future

# %%
def prophet_forecast(series, months_ahead=12, test_months=6) :
    s =	series.copy().reset_index()
    s.columns = ["ds" ,"y"]
    s["ds"] = pd.to_datetime(s["ds"])
    s = s.sort_values("ds")

    train = s.iloc[ : -test_months].copy()
    test = s.iloc[ -test_months:].copy()


    m = Prophet(yearly_seasonality=True, weekly_seasonality=False, daily_seasonality=False)
    m.fit(train)
    future = m.make_future_dataframe(periods=test_months+months_ahead, freq="MS")
    fc = m.predict(future)
    pred_test = fc.tail(test_months+months_ahead).iloc[:test_months]["yhat"].values
    future= fc.tail(test_months+months_ahead).iloc[test_months: ]["yhat"].values
    future_index = pd.date_range(start=series.index.max()+pd.offsets.MonthBegin(1), periods=months_ahead, freq="MS")	
    future_series = pd.Series(future_fc, index=future_index)
    return pred_test,test["y"].values, future_series

# %%
def lstm_forecast(series, months_ahead=12, test_months=6,window=6, n_epochs=100,batch=16):

    s = series.copy().astype(float)
    #scale
    scaler = MinMaxScaler()
    arr = scaler.fit_transform(s.value.reshape(-1,1)).flatten()
    X,y = create_lstm_sequences(arr,window)
    if len(X) < (test_months + 10):
        #not enough data
        test_months = max(1, min(test_months,len(X)//4))
        split = len(X) - test_months 
        X_train, X_test = X[:split] , X [split:]
        Y_train, Y_test	=  y[:split],y[split:]
        X_train = X_train.reshape((X_train.shape(0) , X_train.shape[1], 1))
        X_test = X_test. reshape ( (X_test.shape[0] , X_test.shape[1],1))
        model = Sequential()
        model.add(LSTM(16,input_shape=(window,1)))
        model.add(Dense(1))
        model.compile(optimizer="adam",loss="mse")
        model.fit(X_train,y_train,epochs=epochs,batch_size=batch,verbose=0)
        pred_test_scaled = model.predict(X_test, verbose=0).flatten()
        pred_test = scaler.inverse_transform(pred_test_scaled.reshape(-1,1)).flatten()
        Y_test_inv = scaler.inverse_transform(y_test.reshape (-1,1)).flatten()
        # future iterative prediction 
        last_window=arr[-window:].copy()
        future_scaled=[]
        for _ in range (months_ahead):
            Xin=last_window.reshape(1,window,1)
            yhat=float(model.predict(Xin,verbose=0).flatten()[0])
            future_scaled.append(yhat)
            last_window=np.roll(last_window,-1)
            last_window[-1]=yhat
    

    future_vals=scaler.inverse_transform (np.array(future_scaled).reshape(-1,1)).flatten()
    future_index = pd. date_range (start=series . index . max ( ) +pd. offsets . MonthBegin (1), periods=months_ahead,  freq="MS" )
    future_series = pd. Series (future_vals, index=future_index)
    return pred_test, y_test_inv, future_series

# %%
# #MODEL COMPARISON(PER CATEGORY)+FORECASTING
# def evaluate_models_for_category(cat_name,series):

# MODEL COMPARISON (per category) + Forecasting
#
def evaluate_models_for_category(cat_name, series):
    """
    Fit Regression, ARIMA, Prophet, LSTM. Return:
    -perf table (MAE/RMSE/MAPE)
    forecasts for each model (future series)
    """
    out = {}
    perf_rows = []
    # Regression
    try:
        pred_test, y_test, future = forecast_monthly(series, months_ahead=FORECAST_MONTHS, test_months=TEST_MONTHS)
        perf_rows.append(["Regression", mean_absolute_error(y_test, pred_test), rmse(y_test, pred_test), mape(y_test, pred_test)])
        out["Regression_future"] = future
    except Exception as e:
        out["Regression_future"] = None
        perf_rows.append(["Regression", np.nan, np.nan, np.nan])
    # ARIMA
    try:
        pred_test, y_test, future = arima_forecast(series, months_ahead=FORECAST_MONTHS, test_months=TEST_MONTHS, order=(2, 1, 2))
        perf_rows.append(["ARIMA", mean_absolute_error(y_test, pred_test), rmse(y_test, pred_test), mape(y_test, pred_test)])
        out["ARIMA_future"] = future
    except Exception as e:
        out["ARIMA_future"] = None
        perf_rows.append(["ARIMA", np.nan, np.nan, np.nan])

    #Prophet
    try:
        pred_test, y_test, future = prophet_forecast(series, months_ahead=FORECAST_MONTHS, test_months=TEST_MONTHS)
        perf_rows.append(["Prophet", mean_absolute_error(y_test, pred_test), rmse(y_test, pred_test), mape(y_test, pred_test)])
        out["Prophet_future"] = future
    except Exception as e:
        out["Prophet_future"] = None
        perf_rows.append(["Prophet", np.nan, np.nan, np.nan])
    # LSTM
    try:
        pred_test, y_test, future = lstm_forecast(series, months_ahead=FORECAST_MONTHS, test_months=TEST_MONTHS,
                                                epochs=LSTM_EPOCHS, batch=LSTM_BATCH,
                                                window=LSTM_WINDOW)
        perf_rows.append(["LSTM", mean_absolute_error(y_test, pred_test), rmse(y_test, pred_test), mape(y_test, pred_test)])
        out["LSTM_future"] = future
    except Exception as e:
        out["LSTM_future"] = None
        perf_rows.append(["LSTM", np.nan, np.nan, np.nan])
        perf = pd.DataFrame(perf_rows, columns=["Model", "MAE", "RMSE", "MAPE_3"]).sort_values("RMSE")
        out["perf"] = perf
        return out

# %%
# Choose categories to forecast: top spend categories
forecast_categories = top_cats.copy()
category_forecasts = {}
category_perf_tables = {}
for cat in forecast_categories:
    s = wide[cat].copy()
    #ensure monthly freq index is MS
    s = s.asfreq("MS").fillna(0.0)
    print("\n\n======")
    print(f"FORECASTING CATEGORY: {cat}")
    print("======")
    info = evaluate_models_for_category(cat, s)
    category_forecasts[cat] = info
    category_perf_tables[cat] = info["perf"]
    print("\nPerformance (last months test):")
    print(info["perf"])
    # Plot: actual + best model future forecast (lowest RMSE)
    best_model = info["perf"].iloc[0]["Model"]
    best_future = info.get(f"{best_model}_future", None)
    plt.figure(figsize=(10,4))
    plt.plot(s.index, s.values, label="Actual")
    if isinstance (best_future, pd. Series):
        plt.plot(best_future.index, best_future.values, label=f"{best_model} Forecast")
    plt.title(f"Category Forecast: {cat} (Best: {best_model})")
    plt.xlabel("Month")
    plt.ylabel("Expense")
    plt.legend ()
    plt.tight_layout()
    plt.show()
# Out:
# ...
# FORECASTING CATEGORY: Rent
# ...
#
# Performance (last months test):
#         Model  MAE  RMSE  MAPE_3
# 0  Regression  NaN   NaN     NaN
# 1       ARIMA  NaN   NaN     NaN
# 2     Prophet  NaN   NaN     NaN
# 3        LSTM  NaN   NaN     NaN
# ...
# FORECASTING CATEGORY: Groceries
# ...
#
# Performance (last months test):
#         Model  MAE  RMSE  MAPE_3
# 0  Regression  NaN   NaN     NaN
# 1       ARIMA  NaN   NaN     NaN
# 2     Prophet  NaN   NaN     NaN
# 3        LSTM  NaN   NaN     NaN
# ...
# FORECASTING CATEGORY: Dining
# ...
#
# Performance (last months test):
#         Model  MAE  RMSE  MAPE_3
# 0  Regression  NaN   NaN     NaN
# 1       ARIMA  NaN   NaN     NaN
# 2     Prophet  NaN   NaN     NaN
# 3        LSTM  NaN   NaN     NaN
# ...
# FORECASTING CATEGORY: Utilities
# ...
#
# Performance (last months test):
#         Model  MAE  RMSE  MAPE_3
# 0  Regression  NaN   NaN     NaN
# 1       ARIMA  NaN   NaN     NaN
# 2     Prophet  NaN   NaN     NaN
# 3        LSTM  NaN   NaN     NaN
# ...

# %%
print("\n\n====================")
print("UPCOMING HIGH-SPEND CATEGORIES (Next 12 months)")
print("====================")
# Use LSTM forecast if available else use best model per category
future_table = pd.DataFrame(index=pd.date_range(start=wide.index.max()+pd.offsets.MonthBegin(1), periods=FORECAST_MONTHS, freq="MS"))
for cat in forecast_categories:
    perf = category_forecasts[cat]["perf"]
    best_model = perf.iloc[0]["Model"]
    f = category_forecasts[cat].get(f" (best_model)_future", None)
    if isinstance(f, pd.Series):
        future_table[cat] = f.values
    else:
        future_table[cat] = np.nan

future_table["TOTAL_FORECAST_TOPCATS"] = future_table.sum(axis=1, skipna=True)
# Rank categories by total predicted spend
pred_totals =future_table[forecast_categories].sum().sort_values(ascending=False)
print("\nPredicted total spend by category (next 12 months):")
print(pred_totals)
plt.figure(figsize=(10, 4))
pred_totals.plot(kind="bar")
plt.title("Predicted Total Spend by Category (Next 12 Months)")
plt.xlabel("Category")
plt.ylabel("Predicted Spend")
plt.tight_layout ()
plt.show()
# Out:
# ...
# UPCOMING HIGH-SPEND CATEGORIES (Next 12 months)
# ...
#
# Predicted total spend by category (next 12 months):
# Rent             0.0
# Groceries        0.0
# Dining           0.0
# Utilities        0.0
# Travel           0.0
# Transport        0.0
# Insurance        0.0
# Entertainment    0.0
# dtype: float64

# %%
import matplotlib.pyplot as plt

# ====================
# WHAT-IF SIMULATION MODULE
# ====================

print("\n\n====================")
print("WHAT-IF SIMULATION")
print("====================")
print("Example scenarios implemented:")
print("- Rent increases by 10% next quarter (next 3 months)")
print("- New streaming subscription added (+ fixed amount per month)")
print("- Utility cost reduction (percentage per month)")

# Scenario definitions
SCENARIOS = [
    {
        "name": "Rent +10% next quarter",
        "category": "Rent",
        "type": "pct",
        "value": 0.10,
        "months": 3
    },
    {
        "name": "Add new Streaming subscription",
        "category": "Entertainment",
        "type": "fixed",
        "value": 500.0,
        "months": 12
    },
    {
        "name": "Utilities -5% due to savings",
        "category": "Utilities",
        "type": "pct",
        "value": -0.05,
        "months": 12
    }
]

# Copy forecast table safely
whatif = future_table[forecast_categories].copy()

# Apply scenarios
for sc in SCENARIOS:

    cat = sc["category"]

    # Skip if category not present
    if cat not in whatif.columns:
        print(f"Warning: {cat} not found in forecast categories")
        continue

    months = min(sc["months"], len(whatif))
    idx = whatif.index[:months]

    # Percentage change
    if sc["type"] == "pct":
        whatif.loc[idx, cat] = whatif.loc[idx, cat] * (1 + sc["value"])

    # Fixed addition
    elif sc["type"] == "fixed":
        whatif.loc[idx, cat] = whatif.loc[idx, cat] + sc["value"]

# Total expense after scenario
whatif["TOTAL_AFTER_WHATIF"] = whatif.sum(axis=1, skipna=True)

# Base forecast
base_total = future_table["TOTAL_FORECAST_TOPCATS"].copy()

# Difference between base and adjusted forecast
delta = whatif["TOTAL_AFTER_WHATIF"] - base_total

# ====================
# Graph 1: Base vs What-if
# ====================

plt.figure(figsize=(10,4))

plt.plot(
    base_total.index,
    base_total.values,
    label="Base Forecast (Top Categories)"
)

plt.plot(
    whatif.index,
    whatif["TOTAL_AFTER_WHATIF"].values,
    label="After What-if Simulation"
)

plt.title("What-if Simulation: Base vs Adjusted Forecast")
plt.xlabel("Month")
plt.ylabel("Predicted Expense")

plt.legend()
plt.tight_layout()
plt.show()

# ====================
# Graph 2: Impact per Month
# ====================

plt.figure(figsize=(10,4))

plt.bar(
    delta.index.astype(str),
    delta.values
)

plt.title("What-if Impact (Adjusted - Base)")
plt.xlabel("Month")
plt.ylabel("Expense Change")

plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# ====================
# Summary
# ====================

print("\nWhat-if impact summary (total change across horizon):", float(delta.sum()))
# Out:
# ...
# WHAT-IF SIMULATION
# ...
# Example scenarios implemented:
# - Rent increases by 10% next quarter (next 3 months)
# - New streaming subscription added (+ fixed amount per month)
# - Utility cost reduction (percentage per month)
# What-if impact summary (total change across horizon): 0.0

# %%
# Anomaly Detection (Unusual spending behavior)

print("\n\n====================")
print("ANOMALY DETECTION")
print("====================")

# make sure index is datetime
wide.index = pd.to_datetime(wide.index)

# Monthly anomalies using IsolationForest on TOTAL EXPENSE
monthly_total = wide["TOTAL_EXPENSE"].copy()
monthly_total = monthly_total.asfreq("MS").fillna(0.0)

iso = IsolationForest(contamination=0.05, random_state=42)

labels = iso.fit_predict(monthly_total.values.reshape(-1,1))

anoms = pd.DataFrame(
    {"TOTAL_EXPENSE": monthly_total.values, "Anomaly": labels},
    index=monthly_total.index
)

anomaly_months = anoms[anoms["Anomaly"] == -1]

print("\nAnomalous months (possible unusual spending):")
print(anomaly_months)

plt.figure(figsize=(10,4))

plt.plot(monthly_total.index, monthly_total.values, label="Total Expense")

plt.scatter(
    anomaly_months.index,
    anomaly_months["TOTAL_EXPENSE"],
    label="Anomalies",
    marker="x"
)

plt.title("Monthly Total Expense with Anomaly Flags")
plt.xlabel("Month")
plt.ylabel("Total Expense")

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ...
# ANOMALY DETECTION
# ...
#
# Anomalous months (possible unusual spending):
# Empty DataFrame
# Columns: [TOTAL_EXPENSE, Anomaly]
# Index: []

# %%
#Transaction-level anomalies (if available)
if txn2 is not None and txn_amt_col is not None and txn_date_col is not None:
    tx = txn2.copy()
    tx = tx.sort_values(txn_date_col)
    # simple anomaly threshold by z-score
    amt = tx[txn_amt_col].astype(float)
    z = (amt - amt.mean()) / (amt.std() + 1e-9)
    tx["Anomaly"] = (z.abs() > 3).astype(int)
    print("\nTop 10 transaction anomalies (z-score > 3):")
    print(tx[tx["Anomaly"] == 1].head(10)[[txn_date_col, txn_amt_col] + ([txn_cat_col] if txn_cat_col else [])])
else:
    print("\nTransaction anomaly detection skipped (date/amount columns not detected).")
# Out:
# Transaction anomaly detection skipped (date/amount columns not detected).

# %%
# Classification for Expense Categorization
print("\n\n=========")
print("EXPENSE CATEGORIZATION (OPTIONAL)")
print("====================")

RANDOM_STATE = globals().get("RANDOM_STATE", 42)

if txn2 is not None and txn_cat_col is not None and txn_desc_col is not None:
    from sklearn.model_selection import train_test_split
    from sklearn.feature_extraction.text import CountVectorizer
    from sklearn.linear_model import LogisticRegression
    from sklearn.metrics import classification_report

    dfc = txn2[[txn_desc_col, txn_cat_col]].dropna().copy()
    dfc[txn_desc_col] = dfc[txn_desc_col].astype(str)
    dfc[txn_cat_col] = dfc[txn_cat_col].astype(str)

    if dfc[txn_cat_col].nunique() >= 2 and len(dfc) >= 50:
        X_train, X_test, y_train, y_test = train_test_split(
            dfc[txn_desc_col],
            dfc[txn_cat_col],
            test_size=0.2,
            random_state=RANDOM_STATE,
            stratify=dfc[txn_cat_col],
        )
        vec = CountVectorizer(max_features=3000, stop_words="english")
        Xtr = vec.fit_transform(X_train)
        Xte = vec.transform(X_test)

        clf = LogisticRegression(max_iter=200)
        clf.fit(Xtr, y_train)
        pred = clf.predict(Xte)

        print("\nClassification Report (Category prediction from Description/Merchant):")
        print(classification_report(y_test, pred))
    else:
        print("Not enough labeled category data for classification (need >=2 categories and >=50 rows).")
else:
    print("Classification skipped (need both Category and Description/Merchant text columns).")
# Out:
# ...
# EXPENSE CATEGORIZATION (OPTIONAL)
# ...
# Classification skipped (need both Category and Description/Merchant text columns).

# %%
# FINAL OUTPUTS & INTERPRETATION

print("\n\n==========")
print("FINAL OUTPUTS (WHAT YOU GET)")
print("========")
print("- Forecasts by category (plots + future_table)")
print("- High-spend category ranking (pred_totals)")
print("- What-if simulation (base vs adjusted)")
print("- Anomaly detection (monthly optional transaction-level)")
print("- Model performance comparison per category (MAE/RMSE/MAPE)")
#Save key tables for report usage
future_table_out="expense_forecast_next_12_months_by_category.csv" 
whatif_out="expense_forecast_whatif_adjusted.csv"
future_table.to_csv(future_table_out, index=True)
whatif.to_csv(whatif_out,index=True)
print("\nSaved files:")
print("-", future_table_out)
print("-", whatif_out)
# Out:
# ...
# FINAL OUTPUTS (WHAT YOU GET)
# ...
# - Forecasts by category (plots + future_table)
# - High-spend category ranking (pred_totals)
# - What-if simulation (base vs adjusted)
# - Anomaly detection (monthly optional transaction-level)
# - Model performance comparison per category (MAE/RMSE/MAPE)
#
# Saved files:
# - expense_forecast_next_12_months_by_category.csv
# - expense_forecast_whatif_adjusted.csv

# %%
txn.head()
# Out:
#          date  user_id   category       merchant  amount_inr payment_method  \
# 0  01-01-2019     1001  Groceries          DMart      737.17            UPI
# 1  01-01-2019     1001  Education          Udemy      293.19            UPI
# 2  01-01-2019     1001  Groceries          DMart      348.53            UPI
# 3  01-01-2019     1001       Rent  ApartmentMgmt    11876.12    Credit Card
# 4  02-01-2019     1001  Transport          Metro      203.84            UPI
#
#    is_recurring recurring_code
# 0         False            NaN
# 1         False            NaN
# 2         False            NaN
# 3          True           RENT
# 4         False            NaN

# %%
monthly.head()
# Out:
#    year  month   period       category  monthly_expense_inr
# 0  2019      1  2019-01           Rent             18840.02
# 1  2019      1  2019-01      Groceries              9035.66
# 2  2019      1  2019-01      Utilities              4110.39
# 3  2019      1  2019-01      Transport              2570.13
# 4  2019      1  2019-01  Entertainment              1896.88
